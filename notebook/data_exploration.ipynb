# %% [markdown]
# # Data Loading
#
# Load data using the data_loader module

# %%
import sys
sys.path.append('..')

from src.data_loader import df1

# Display basic info for Data Extraction sheet
print(f"Shape: {df1.shape}")
print(f"Columns: {list(df1.columns)}")
print("\nFirst 10 rows:")
display(df1.head(10))
# Out:
# ...
# Data Extraction Sheet (Grossi et al.)
# ...
# Shape: (1, 1)
# Columns: ['README']
#
# First 10 rows:
#                                               README
# 0  S4_Table.xls: Piloted data extraction sheet: T...
